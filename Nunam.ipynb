# %%
# Importing the needed libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
from sklearn.model_selection import train_test_split
import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
# Read csv file
df1 = pd.read_excel("/content/drive/MyDrive/5308.xls")
df1
# Out:
#                               Testing Information Unnamed: 1 Unnamed: 2  \
# 0                       240067-3-5-2818573766.xls        NaN        NaN
# 1                             2019-11-18 12:03:13        NaN        NaN
# 2  E:\cdc-sn\18.11.2019\240067-3-5-2818573766.xls        NaN        NaN
# 3                         Cycle Mode:Charge First        NaN        NaN
# 4                                   Process Name:   Cap-3000        NaN
# 5                                       Equipment       Unit    Channel
# 6                                              67          3          5
#
#                Unnamed: 3    Unnamed: 4           Unnamed: 5  \
# 0                     NaN           NaN                  NaN
# 1                     NaN           NaN                  NaN
# 2                     NaN           NaN                  NaN
# 3                     NaN           NaN                  NaN
# 4                     NaN           NaN                  NaN
# 5  Battery of Number(P/N)  File of Step           Start time
# 6     2019-11-15 19-28-31             -  2019-11-15 19:28:31
#
#             Unnamed: 6    Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0                  NaN           NaN        NaN        NaN
# 1                  NaN           NaN        NaN        NaN
# 2                  NaN           NaN        NaN        NaN
# 3                  NaN           NaN        NaN        NaN
# 4                  NaN           NaN        NaN        NaN
# 5             End Time  Grading File      Grade     Remark
# 6  2019-11-16 03:38:33           NaN          0        NaN

# %%
# Read csv file
df2 = pd.read_excel("/content/drive/MyDrive/5329.xls")
df2
# Out:
#                               Testing Information Unnamed: 1 Unnamed: 2  \
# 0                       240067-3-1-2818573768.xls        NaN        NaN
# 1                             2019-11-18 12:02:58        NaN        NaN
# 2  E:\cdc-sn\18.11.2019\240067-3-1-2818573768.xls        NaN        NaN
# 3                         Cycle Mode:Charge First        NaN        NaN
# 4                                   Process Name:   Cap-3000        NaN
# 5                                       Equipment       Unit    Channel
# 6                                              67          3          1
#
#                Unnamed: 3    Unnamed: 4           Unnamed: 5  \
# 0                     NaN           NaN                  NaN
# 1                     NaN           NaN                  NaN
# 2                     NaN           NaN                  NaN
# 3                     NaN           NaN                  NaN
# 4                     NaN           NaN                  NaN
# 5  Battery of Number(P/N)  File of Step           Start time
# 6     2019-11-15 19-38-07             -  2019-11-15 19:38:07
#
#             Unnamed: 6    Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0                  NaN           NaN        NaN        NaN
# 1                  NaN           NaN        NaN        NaN
# 2                  NaN           NaN        NaN        NaN
# 3                  NaN           NaN        NaN        NaN
# 4                  NaN           NaN        NaN        NaN
# 5             End Time  Grading File      Grade     Remark
# 6  2019-11-16 03:51:27           NaN          0        NaN

# %%
# Get a quick info about dataset
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Testing Information  7 non-null      object
#  1   Unnamed: 1           3 non-null      object
#  2   Unnamed: 2           2 non-null      object
#  3   Unnamed: 3           2 non-null      object
#  4   Unnamed: 4           2 non-null      object
#  5   Unnamed: 5           2 non-null      object
#  6   Unnamed: 6           2 non-null      object
#  7   Unnamed: 7           1 non-null      object
#  8   Unnamed: 8           2 non-null      object
#  9   Unnamed: 9           1 non-null      object
# dtypes: object(10)
# memory usage: 688.0+ bytes

# %%
# Detecting the null values
df1.isnull().sum()
# Out:
# Testing Information    0
# Unnamed: 1             4
# Unnamed: 2             5
# Unnamed: 3             5
# Unnamed: 4             5
# Unnamed: 5             5
# Unnamed: 6             5
# Unnamed: 7             6
# Unnamed: 8             5
# Unnamed: 9             6
# dtype: int64

# %%
# Get a quick info about dataset
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Testing Information  7 non-null      object
#  1   Unnamed: 1           3 non-null      object
#  2   Unnamed: 2           2 non-null      object
#  3   Unnamed: 3           2 non-null      object
#  4   Unnamed: 4           2 non-null      object
#  5   Unnamed: 5           2 non-null      object
#  6   Unnamed: 6           2 non-null      object
#  7   Unnamed: 7           1 non-null      object
#  8   Unnamed: 8           2 non-null      object
#  9   Unnamed: 9           1 non-null      object
# dtypes: object(10)
# memory usage: 688.0+ bytes

# %%
df1.columns
# Out:
# Index(['Testing Information', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Testing Information', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9'],
#       dtype='object')
